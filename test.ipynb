# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import os 
from shapely.geometry import LineString, MultiLineString
import shapely.geometry
import pytz
import datetime
import pyproj #import Proj, transform
print(pyproj.__version__)  # 2.4.1
print(pyproj.proj_version_str)  # 6.2.1
import plotly.express as px
from extract import extract
# Out:
# 3.3.1
# 8.2.0

# %%
folder = "data/florence_run_csv/"
track = pd.DataFrame()
x = 0
for file in os.listdir(folder):
    if file.endswith(('.csv')):
        try:
            data = pd.read_csv(folder + file)
            track = track.append(extract(data, file))
            x +=1
        except:
            print("Error", file)
print(x)
track_plot = track[["geometry", "Pace Mi/Hr"]].copy()

# # Add the Florence Plot
gdf = gpd.read_file("data/florence_city_gps/florence_city.gpx", layer='tracks', crs = 4326)

gdf = gdf[["geometry"]]

track_plot = gpd.GeoDataFrame(track_plot, geometry="geometry", crs = 4326)

track_plot = track_plot.append(gdf)

track_plot["Pace Mi/Hr"] = track_plot["Pace Mi/Hr"].fillna(0)
# Out:
# 46

# %%
track_plot.explore(column="Pace Mi/Hr", cmap="gist_rainbow")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_800afcce556d706e6bda7f5db56e437c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_800afcce556d706e6bda7f5db56e437c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_800afcce556d706e6bda7f5db56e437c = L.map(
#                 &quot;map_800afcce556d706e6bda7f5db56e437c&quot;,
#                 {
#                     center: [43.7806673, 11.244332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_800afcce556d706e6bda7f5db56e437c);
#
#
#
#
#
#             var tile_layer_4c6291661157f449505b5da9c2f843e6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_800afcce556d706e6bda7f5db56e437c);
#
#
#             map_800afcce556d706e6bda7f5db56e437c.fitBounds(
#                 [[43.7258715, 11.1497597], [43.8354631, 11.3389043]],
#                 {}
#             );
#
#
#         function geo_json_b73097466871e4507ae20f5ff486d8db_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;: case &quot;35&quot;: case &quot;206&quot;: case &quot;210&quot;: case &quot;622&quot;: case &quot;628&quot;: case &quot;660&quot;: case &quot;733&quot;: case &quot;754&quot;: case &quot;766&quot;: case &quot;797&quot;: case &quot;808&quot;: case &quot;847&quot;: case &quot;911&quot;: case &quot;912&quot;: case &quot;1022&quot;: case &quot;1074&quot;: case &quot;1139&quot;: case &quot;1201&quot;: case &quot;1213&quot;: case &quot;1255&quot;: case &quot;1296&quot;: case &quot;1481&quot;: case &quot;1543&quot;: case &quot;1701&quot;: case &quot;1769&quot;: case &quot;1809&quot;: case &quot;1838&quot;: case &quot;2067&quot;: case &quot;2069&quot;: case &quot;2072&quot;: case &quot;2073&quot;: case &quot;2146&quot;: case &quot;2147&quot;: case &quot;2148&quot;: case &quot;3418&quot;: case &quot;4412&quot;: case &quot;4413&quot;: case &quot;4611&quot;: case &quot;4703&quot;: case &quot;4727&quot;: case &quot;4819&quot;: case &quot;4833&quot;: case &quot;5127&quot;: case &quot;5128&quot;: case &quot;5146&quot;: case &quot;5191&quot;: case &quot;5389&quot;: case &quot;5485&quot;: case &quot;5486&quot;:
#                     return {&quot;color&quot;: &quot;#00a5ff&quot;, &quot;fillColor&quot;: &quot;#00a5ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;6&quot;: case &quot;94&quot;: case &quot;221&quot;: case &quot;293&quot;: case &quot;330&quot;: case &quot;524&quot;: case &quot;950&quot;: case &quot;951&quot;: case &quot;1713&quot;: case &quot;1919&quot;: case &quot;1920&quot;: case &quot;2201&quot;: case &quot;2204&quot;: case &quot;2276&quot;: case &quot;2431&quot;: case &quot;2528&quot;: case &quot;3296&quot;: case &quot;3944&quot;: case &quot;3945&quot;: case &quot;3949&quot;: case &quot;4661&quot;: case &quot;4788&quot;: case &quot;4988&quot;: case &quot;5032&quot;: case &quot;5123&quot;: case &quot;5183&quot;: case &quot;5305&quot;: case &quot;5309&quot;: case &quot;5520&quot;:
#                     return {&quot;color&quot;: &quot;#00ff3b&quot;, &quot;fillColor&quot;: &quot;#00ff3b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;152&quot;: case &quot;240&quot;: case &quot;953&quot;: case &quot;1020&quot;: case &quot;1385&quot;: case &quot;1659&quot;: case &quot;1913&quot;: case &quot;1914&quot;: case &quot;1944&quot;: case &quot;1948&quot;: case &quot;2296&quot;: case &quot;2524&quot;: case &quot;2568&quot;: case &quot;2569&quot;: case &quot;2570&quot;: case &quot;2889&quot;: case &quot;5349&quot;: case &quot;5418&quot;:
#                     return {&quot;color&quot;: &quot;#00ff16&quot;, &quot;fillColor&quot;: &quot;#00ff16&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;44&quot;: case &quot;503&quot;: case &quot;1039&quot;: case &quot;1694&quot;: case &quot;2975&quot;: case &quot;3081&quot;: case &quot;3294&quot;: case &quot;3295&quot;: case &quot;3646&quot;: case &quot;3941&quot;: case &quot;3947&quot;: case &quot;4017&quot;: case &quot;5377&quot;: case &quot;5643&quot;:
#                     return {&quot;color&quot;: &quot;#00ff26&quo
